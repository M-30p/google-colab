# %%
import csv
f1-open("/content/emp.csv","r")
f2 = open("sal.csv","r")
f3= open("emp_sal.csv", "w")
d1-list (csv.reader (f1, delimiter=','))
d2=list(csv.reader (f2, delimiter=','))
print("\n\nFilel Contents:", d1) 
print("\n\nFile2 Contents:",d2)
d3= []
for
i in range(len(d1)): 
  d3.append(d1[i] + d2[i])
print(d3)
CW = csv.writer (f3) cw.writerows (d3)
f1.close()
f2.close()
f3.close()
f=open("emp_sal.csv","r")
contents-f.read()
lines-contents.split("\n")
sal=[]
for i in lines:
   words-1.split(",")
   print (words)
sal.append(int (words [4]))
print("Maximum Salary",max(sal))
print("Minimum Salary", min(sal)) 
print("Sum of Salary", sum(sal))
print("Average Salary", sum(sal)/len(sal))

# %%
import csv
import datetime
from datetime import date
from datetime import datetime

def calculate_age(birthDate):
    today= date.today() 
    age = today.year - birthDate.year - ((today.month, today.day) < (birthDate.month,birthDate.day))
    return age

f1=open("/content/dob.csv","r")

data = list(csv.reader(f1))
bdate =[]
age =[]
dollers =[]
print(data)

for i in range(len(data)):
    print(data[i][1])
    bdate.append(datetime.strptime(data[i][1],'%d%m%y').date())

for i in range(len(data)):
    age.append()

# %%
import csv
from datetime import date 

def calculateAge(birthDate):
  today= date.today() 
  age = today.year birthDate.year ((today.month, today.day) < (birthDate.month,
  return age)


f1 = open("/content/EmpInfo.csv","r")

data= list(csv.reader(1))

bdate = []
age []
dollars = []
