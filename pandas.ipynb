# %%
import pandas as pd

a=[10,70,20]

myvar = pd.Series(a)
print(myvar)
# Out:
# 0    10
# 1    70
# 2    20
# dtype: int64

# %%
import pandas as pd

a=[10,70,20]

myvar = pd.Series(a,index = ["x","y","z"])
print(myvar)
# Out:
# x    10
# y    70
# z    20
# dtype: int64

# %%
import pandas as pd
result = {"SIC":55,"AM":60,"EDS":66}
sr = pd.Series(result)
print(sr)
# Out:
# SIC    55
# AM     60
# EDS    66
# dtype: int64

# %%
import pandas as pd
result = {"SIC":55,"AM":60,"EDS":66}
sr = pd.Series(result,index = ["SIC","EDS"])
print(sr)
# Out:
# SIC    55
# EDS    66
# dtype: int64

# %%
import pandas as pd

data = {
    "Course": ["SIC","DT","EDS","ENG"],
    "Credits": [4,3,4,2]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Course  Credits
# 0    SIC        4
# 1     DT        3
# 2    EDS        4
# 3    ENG        2

# %%
print(df.loc[0])
# Out:
# Course     SIC
# Credits      4
# Name: 0, dtype: object

# %%
print(df.loc[[0,1]])
# Out:
#   Course  Credits
# 0    SIC        4
# 1     DT        3

# %%
import pandas as pd

df = pd.read_csv('/content/result2.csv')

print(df)
# Out:
#       Name  Maths  English  Physics  Chemistry  Biology
# 0     Amit     75       45       60         65       62
# 1    Sumit     63       56       58         62       60
# 2    Anita     80       58       74         58       65
# 3   Sujata     42       53       57         56       45
# 4     Ajit     58       69       65         58       64
# 5    Sujit     57       68       90         97       67
# 6      Ana     78       75       87         89       65
# 7     Tina     85       58       89         56       63
# 8     Mina     57       45       54         66       64
# 9     Lata     54       74       23         77       62
# 10   smita     89       54       54         23       60
# 11  asmita     54       55       63         74       65
# 12   suraj     63       66       78         56       33
# 13   netra     23       87       44         87       87

# %%
import pandas as pd

df = pd.read_json('/content/sampleJSON (1).js')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df = pd.read_json('/content/SCORE.JS')

print(df.to_string())
# Out:
#    SIC  EDS  AM
# 0   60  110  10
# 1   60  120  20
# 2   60  115  30
# 3   45  125  35
# 4   45  130  40
# 5   60  150  60

# %%
import pandas as pd

df = pd.read_csv('/content/result2.csv')

print(df.head(10))
# Out:
#      Name  Maths  English  Physics  Chemistry  Biology
# 0    Amit     75       45       60         65       62
# 1   Sumit     63       56       58         62       60
# 2   Anita     80       58       74         58       65
# 3  Sujata     42       53       57         56       45
# 4    Ajit     58       69       65         58       64
# 5   Sujit     57       68       90         97       67
# 6     Ana     78       75       87         89       65
# 7    Tina     85       58       89         56       63
# 8    Mina     57       45       54         66       64
# 9    Lata     54       74       23         77       62

# %%
all_data=pd.read_csv('/content/practicaldata.csv')

# %% [markdown]
# 1.What was the best month for sales How much was earned that month?

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int')*all_data['Price Each'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-21-585209c38c63> in <cell line: 1>()
# ----> 1 all_data['Sales'] = all_data['Quantity Ordered'].astype('int')*all_data['Price Each'].astype('float')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
all_data.grouby(['Month']).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e92707c3523e> in <cell line: 1>()
# ----> 1 all_data.grouby(['Month']).sum()
#
# NameError: name 'all_data' is not defined
