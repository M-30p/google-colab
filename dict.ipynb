# %%
D=dict(name = 'bob',
       age = 25,
       job ='Dev')

print(D)
# Out:
# {'name': 'bob', 'age': 25, 'job': 'Dev'}

# %%
[] #Create a dictionary with list of zipped keys/values
keys = ['name','age','job']
values = ['Bob', 25,'Dev']

# %%
keys = ['name','age','job']
values = ['Bob',25,'Dev']

D = dict(zip(keys,values))

print(D)
# Out:
# {'name': 'Bob', 'age': 25, 'job': 'Dev'}
